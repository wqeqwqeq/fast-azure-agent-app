# %%
from app.opsagent.utils.keyvault import AKV

# %%
from app.config import get_settings

# %%
app_settings = get_settings()

# %%
app_settings
# Out:
# Settings(resource_prefix='gpt-mock-ui', chat_history_mode='redis', conversation_history_days=7, postgres_port=5432, postgres_admin_login='pgadmin', postgres_database='chat_history', postgres_sslmode='require', redis_port=6380, redis_ssl=True, redis_ttl_seconds=1800, dynamic_plan=False, show_func_result=True, default_model='gpt-4o-mini', available_models=['gpt-4o-mini', 'gpt-4o', 'gpt-4.1', 'gpt-3.5-turbo'], local_test_client_id='00000000-0000-0000-0000-000000000001', local_test_username='local_user')

# %%
akv = AKV(vault_name=app_settings.key_vault_name)

# %%
akv.list_secrets()
# Out:
# ['APPLICATIONINSIGHTS-CONNECTION-STRING',
#  'POSTGRES-ADMIN-PASSWORD',
#  'postgres-connection-string',
#  'REDIS-PASSWORD']
